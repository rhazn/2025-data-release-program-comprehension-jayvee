# %% [markdown]
# # Data preparation

# %% [markdown]
# # Extract variables from raw experiment data

# %%
import pandas as pd
from limepy.wrangle import Survey
import pandas as pd
import os
import textwrap

from util import getExperimentSequence, getTaskCorrectness, getTaskDurationSeconds, getTaskFromLocation

cnx = sqlite3.connect('data/data_anon.db')

df = pd.read_sql_query("SELECT * FROM events", cnx)

df['task'] = df['location'].map(getTaskFromLocation)

results = pd.DataFrame(columns=[
    'student_id_anon',
    'seq',
    't1_time',
    't1_correctness',
    't2_time',
    't2_correctness',
    'jv_time',
    'py_time',
    'jv_correctness',
    'py_correctness',
])

for experimentId in df['experiment'].unique():
    seq = getExperimentSequence(experimentId, df)

    t1time = getTaskDurationSeconds(experimentId, 1, df)
    t2time = getTaskDurationSeconds(experimentId, 2, df)

    t1correctness = getTaskCorrectness(experimentId, 1, df)
    t2correctness = getTaskCorrectness(experimentId, 2, df)

    results = pd.concat([
        results,
        pd.DataFrame({
            'student_id_anon': experimentId,
            'seq': seq,
            't1_time': t1time,
            't1_correctness': t1correctness,
            't2_time': t2time,
            't2_correctness': t2correctness,
            'jv_time': t1time if seq == 'AB' else t2time,
            'py_time': t2time if seq == 'AB' else t1time,
            'jv_correctness': t1correctness if seq == 'AB' else t2correctness,
            'py_correctness': t2correctness if seq == 'AB' else t1correctness,
        }, index=[experimentId]
    )], ignore_index=True)
# Out:
# /var/folders/tq/ppy7x00d4kn0z3bgzscqy3mc0000gp/T/ipykernel_27115/4156135912.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([

# %% [markdown]
# # Merge results and entry survey data

# %%
entrySurvey = pd.read_csv('./data/participants.csv', dtype = {'student_id_anon':str})

# set all dataframes to use the anon student id as index
entrySurvey.set_index('student_id_anon', inplace=True, drop=True)
results.set_index('student_id_anon', inplace=True, drop=False)

# merge the group assignments into the survey responses
df = results.merge(right=entrySurvey, left_index=True, right_index=True, how='left')

df.to_csv('./data/generated/results_anon.csv', index=False)

df
# Out:
#                 student_id_anon seq   t1_time  t1_correctness   t2_time  \
# student_id_anon
# 159                         159  BA  532.2740        1.000000  326.7220
# 133                         133  BA  402.5120        0.916667  147.3720
# 124                         124  AB  351.3654        1.000000  299.2236
# 83                           83  BA  359.5460        1.000000  259.6020
# 13                           13  BA  152.4110        0.916667  195.2440
# 55                           55  AB  559.6420        0.916667  254.1560
# 163                         163  AB  405.2240        1.000000  207.3460
# 82                           82  AB  504.2530        0.916667  355.2630
# 43                           43  BA  494.0250        0.916667  524.6720
# 155                         155  AB  502.0510        0.833333  699.2710
# 160                         160  BA  538.8330        0.916667  305.8100
# 102                         102  BA  200.2850        0.750000  255.3760
# 99                           99  AB  150.5550        1.000000  248.3620
# 1                             1  AB  369.3060        1.000000  502.0740
# 105                         105  BA  503.6400        0.833333  332.0140
# 16                           16  BA  189.8040        0.916667  136.2020
# 14                           14  AB  196.3220        1.000000  235.1310
# 91                           91  BA  321.8360        0.833333  236.3070
# 78                     0.909091        6         3      3      1      3
# 123                    0.916667        9         4      4      1      3
# 41                     1.000000       10         5      5      1      4
# 166                    1.000000        9         4      5      2      3
# 51                     0.916667       10         5      5      1      4
# 135                    1.000000        5         3      3      1      3
# 76                     0.916667        8         4      5      1      3
# 110                    0.909091        8         5      5      1      4
# 11                     0.818182        6         3      3      1      2
# 165                    0.909091        7         3      4      1      3
# 116                    0.916667       10         5      5      1      1
# 152                    1.000000        6         3      4      1      3
# 146                    1.000000        9         3      2      1      3
# 161                    0.916667        6         2      2      1      2
# 131                    1.000000        7         3      3      1      2
# 7                      1.000000        8         4      3      1      2
# 57                     1.000000        7         3      4      1      2
# 24                     1.000000        8         4      4      1      5
# 108                    0.909091        9         4      4      2      4
# 0                      1.000000        1         1      2      1      1
# 26                     1.000000        8         4      4      1      4
# 52                     0.916667        5         3      3      1      3
# 18                     1.000000        5         3      2      1      1
# 120                    1.000000        8         5      5      1      2
# 84                     0.909091       10         5      5      1      5
# 126                    1.000000        5         2      3      1      2
# 68                     0.909091        8         3      3      1      2
# 151                    0.818182        8         4      4      4      3
# 103                    0.909091        7         3      3      1      1
# 48                     1.000000        8         4      5      1      2
# 158                    0.833333        8         4      4      2      4
# 128                    0.909091        8         4      5      1      2
# 162                    1.000000        7         3      3      1      3
# 27                     0.916667        8         3      4      1      2
# 4                      0.909091        8         3      5      1      4
# 9                      1.000000        3         2      2      1      2

# %% [markdown]
# ## Convert survey data readable dataframes

# %%
with open('./data/limesurvey_survey_structure.lss') as surveyStructure:
    structure = surveyStructure.read()
with open('./data/limesurvey_survey_answers.csv') as surveyAnswers:
     df = pd.read_csv('./data/limesurvey_survey_answers.csv', sep=',')

survey = Survey(df, structure, language='en')
survey.readable_df

readableSurvey = survey.readable_df.rename(columns={
    'How difficult was it to understand the data pipeline written in <strong>Jayvee</strong>?': 'difficultyJV',
    'How difficult was it to understand the data pipeline written in <strong>Python</strong>?': 'difficultyPY',
    'What makes data pipelines written in <strong>Jayvee</strong> difficult/easy to understand?': 'reasonsJV',
    'What makes data pipelines written in <strong>Python</strong> difficult/easy to understand?': 'reasonsPY',
    'What are the <strong>differences</strong> <strong>between Jayvee and Python</strong> that influence\xa0how easy / hard it is to understand data pipelines?': 'differences',
})

readableSurvey = readableSurvey[[
     'difficultyJV',
     'difficultyPY',
     'reasonsJV',
     'reasonsPY',
     'differences',
]]

readableSurvey.to_csv('./data/generated/survey.csv', index=False)

readableSurvey
# Out:
#    difficultyJV difficultyPY  \
# 0          Easy       Medium
# 1          Easy       Medium
# 2        Medium         Easy
# 3          Easy    Very easy
# 4          Easy       Medium
# 5        Medium       Medium
# 6        Medium       Medium
# 7          Easy       Medium
# 8          Easy       Medium
# 9          Easy         Easy
# 10         Easy         Easy
# 11         Easy    Very easy
# 12    Very easy       Medium
# 13         Easy       Medium
# 14    Very easy       Medium
# 15    Very easy         Easy
# 16         Easy       Medium
# 17         Easy         Easy
# 18         Easy       Medium
# 19         Easy    Very easy
# 20         Easy    Very easy
# 21       Medium         Easy
# 22         Easy       Medium
# 23         Easy         Easy
# 24       Medium         Easy
# 25         Hard         Easy
# 26    Very easy    Very easy
# 27       Medium         Easy
# 28       Medium       Medium
# 29    Very easy       Medium
# 30         Easy       Medium
# 31         Easy       Medium
# 32       Medium         Easy
# 33         Easy       Medium
# 34    Very easy         Easy
# 35    Very easy         Easy
# 36       Medium         Easy
# 37       Medium       Medium
# 38       Medium         Easy
# 39         Easy       Medium
# 40         Easy    Very easy
# 41         Easy       Medium
# 42    Very easy         Easy
# 43       Medium    Very easy
# 44    Very easy         Easy
# 45       Medium         Easy
# 46         Easy       Medium
# 47       Medium         Easy
# 48         Easy         Easy
# 49         Easy       Medium
# 50    Very easy       Medium
# 51         Hard         Easy
# 52    Very easy       Medium
# 53    Very easy         Easy
# 54    Very easy    Very easy
# 55         Easy         Easy
#
#                                             reasonsJV  \
# 0   easy:\n- apart from the block definitions you ...
# 1   According to me line by line approach make jay...
# 2                                                 NaN
# 3   new language.\nmust write it many times to get...
# 4   I think validating a columns values, would be ...
# 5   I find the descriptions in the documentation t...
# 6                                                 NaN
# 7   the difference in syntax was so interesting to...
# 8   The best part in jayvee is block type coding i...
# 9   You can see the overview of pipeline at the be...
# 10  I'm not sure, but the name of some of the bloc...
# 11  The pipeline is easy to understand as jayvee i...
# 12  code structured into blocks and self-explanato...
# 13  The structure and and the intentions of the bl...
# 14  The data pipelines written in jayvee is easy t...
# 15  Jayvee pipeline was easier for me because of t...
# 16  The syntax where the different blocks are pipe...
# 17  Names of the blocks are familiar with the conc...
# 18  The pipeline gives a very quick overview over ...
# 19  the easiest way to make it understandable is t...
# 20                Need to think before swap the steps
# 21  It has some level of dificulty because of the ...
# 22  Since the language is new, some blocks are unk...
# 23  the constrain declaration part in the middle o...
# 24  jayvee is easy to understand because of the li...
# 25  it is new so i think it was not easy to unders...
# 26  easy:\n* overview in the beginning\n* naming o...
# 27  it is hard to say but i felt like codes repres...
# 28  When not being used to jayvee you would be fir...
# 29  easy: defined structure, esp. at the beginning...
# 30  The initial definition of the pipeline steps g...
# 31  Easy:\nIt has a very structured layout with ve...
# 32  The pipeline was easy to understand because th...
# 33  The difficult part is delimiter which we can s...
# 34  Block types make it quite easy to understand w...
# 35  - Jayvee code steps are directly mapped to the...
# 36  Lack of instant understanding/ experience in t...
# 37  The names of the blocks usually indicate rathe...
# 38  The structure of the code was a bit difficult ...
# 39  The pipeline flow easily explained that what w...
# 40  Mainly due to the code structure/layout, need ...
# 41  Very clear, because of blockTypes, which give ...
# 42  The code structure and syntax makes it easy to...
# 43  I am not familiar with the strategy : showing ...
# 44  Jayvee is much easier to understand because ev...
# 45  Jayvee is also pretty easy to understand becau...
# 46  the code was understandable as the naming conv...
# 47                                                NaN
# 48  well written and structured code in a flow whi...
# 49  data pipelines in Jayvee is easier to understa...
# 50  Jayvee seems to be quite less computer languag...
# 51  I found the Jayvee code structure a bit diffic...
# 52  Simple syntax and in code are in one flow (i.e...
# 53  I think it is easier to understand in Jayvee a...
# 54  Automatic piping (sometimes it's not 100% clea...
# 55  Especially the beginning of the pipeline, wher...
#
#                                             reasonsPY  \
# 0   easy:\n- the syntax of Python is very clean fo...
# 1   In python, we have to understand the code prop...
# 2                                                 NaN
# 3                              just about practicing.
# 4                                                 NaN
# 5   Just the amount of online resources available ...
# 6                                                 NaN
# 7   python is the language i have written and work...
# 8   python is little difficult to read and its dif...
# 9      Syntax in python is really easy to understand
# 10  It was not that hard to understand it, but a b...
# 11  I have worked with python so I was aware what ...
# 12  some functions like lambda, list comprehension...
# 13  \nPython is a little bit harder to understand ...
# 14  The code written in python might make some con...
# 15  For the Python pipeline, I also think it was e...
# 16  Python is also not hard to read, but the const...
# 17  It is the most common tool that used in the ar...
# 18  The naming of python functions might not be as...
# 19  probably the previous familiarity with Python ...
# 20  I'm little aware to the python that's why it i...
# 21  I think it is easier because I'm programming w...
# 22  Need to read the full code to understand what ...
# 23  There are various libraries available for pyth...
# 24  Python has lot of functionality and i think th...
# 25                         easy to understand or read
# 26  easy:\n* dataframes have a very easy to unders...
# 27  actually i got a lot experience with python th...
# 28  Python has many build-in functions that are so...
# 29  no structure, every pipeline is a new pipeline...
# 30  It does not have an 'overview' of what is done...
# 31  Easy:\nFamiliarity of having is used before.\n...
# 32            I have a better understanding of python
# 33                   Have to import lot of libraries.
# 34  I think that also in Python, the pipeline in t...
# 35  - It's easier as I was comfortable with Python...
# 36                  Experience in Python for 3 years.
# 37  In this very script like fashion, we have no r...
# 38  Easily readable, close to natural language. No...
# 39  the flow was different. there was some options...
# 40  The code was in order & much simple to underst...
# 41  So many features makes it more difficult to un...
# 42  I have more experience with python, so it was ...
# 43  I am using python for a long time so I know it...
# 44  The pipeline in python has no specific structu...
# 45  Gone through python documentation many times f...
# 46  the code was not clearly written. using a prop...
# 47                                                NaN
# 48  code is written is written well -defined struc...
# 49  In python, there are many varieties and differ...
# 50  Python, even though easier to understand than ...
# 51  Easy to read and code as the language keywords...
# 52           Same but need to debug more than Jayvee.
# 53  In pzthon it can also be understood but it is ...
# 54  easy: python syntax which is common\nhard: pot...
# 55  sometimes it is a bit unstructured to read Pyt...
#
#                                           differences
# 0   - the functional approach of Jayvee may be new...
# 1   in jayvee we have different block for the pipe...
# 2                                                 NaN
# 3   I think Jayvee has more  scripts and blocks.\n...
# 4   Compared to Jayvee, many variables and reassig...
# 5   The documentation and support from the python ...
# 6                                                 NaN
# 7   the differencies in syntax sometimes make it h...
# 8   jayvee is kind a block type language, its spec...
# 9   python documentation is more understandable an...
# 10  Jayvee is more limited, so the options are lim...
# 11  Differences between them: \nIf I would have se...
# 12  python code would need comments to explain the...
# 13  The Documentation of the codes is different. P...
# 14  When its come to compare the two language I wi...
# 15  For the Python pipeline, I also think it was e...
# 16  Jayvee code feels more specialized to the task...
# 17  i think the structure of the jayvee that allow...
# 18  Mostly the structuring in blocks and naming of...
# 19  Overall the blocks in Jayvee makes it very cle...
# 20  Jayvee has different bloc which can able to ex...
# 21  Jayvee is based of base type classes encasulad...
# 22  The blocks and their names made it easy to und...
# 23  The Jayvee documentation is more naive user fr...
# 24  functionality: Python has a lot of functions\n...
# 25                                                NaN
# 26  1) The concept of blocks: you can manually cre...
# 27  as i understand functions make easy to python ...
# 28  I think Python has the advantage that the line...
# 29  python can be debugged in order to see steps/w...
# 30  As mentioned, the pipeline overview in jayvee ...
# 31  Syntax being used. Jayvee has a very human lik...
# 32  Mostly how t h blocks were structured, they ma...
# 33  Jayvee has a better code flow definition than ...
# 34  I think the difference might have mostly to do...
# 35  - Python is  less intuitive compared to Jayvee...
# 36  Jayvee seems more efficient for the task like ...
# 37  Jayvee is specialized to represent pipelines, ...
# 38  Both are similar but I think Python is more re...
# 39  I really like jayvee since it is simpler and u...
# 40                                     Code Structure
# 41  Less features in Jayvee makes it more easier +...
# 42  In Jayvee the code is written in simple struct...
# 43  As a programming language I only know Python s...
# 44  Jayvee is much easier to learn and understand ...
# 45                                                NaN
# 46  naming conventions used in both, functions wer...
# 47                                                NaN
# 48  Jayvee has clear and direct "blocks" and "inte...
# 49  The relevant fixed standard to write in the la...
# 50                Block wise pipeline, easier syntax.
# 51  I would say the structure of the code, in pyth...
# 52                              Simple to understand.
# 53  Jayvee looks much more focused on building and...
# 54  I feel like python gives you more controll and...
# 55  Its easier to prevent messy and unstructured C...

# %% [markdown]
# # Export free text responses

# %%
survey = pd.read_csv('./data/generated/survey.csv')
survey = survey.fillna('')

os.makedirs('./data/generated/survey_responses', exist_ok=True)

def wrap_text_with_max_width(text):
    wrapped_text = ""
    for line in text.splitlines():
        wrapped_text += textwrap.fill(line, subsequent_indent='    ') + '\n'
    return wrapped_text

for id, row in survey.iterrows():
    if (len(row['reasonsJV']) + len(row['reasonsPY']) + len(row['differences']) == 0):
            print(f'No content in response {id}, skipping.')
            continue
    
    with open(f'./data/generated/survey_responses/{id}.txt', mode='w') as f:
        f.writelines(
        f'''_____ What makes data pipelines written in Jayvee difficult/easy to understand? _____
_____ JV ({row['difficultyJV']}) _____

{wrap_text_with_max_width(row['reasonsJV'])}

_____ What makes data pipelines written in Python difficult/easy to understand? _____
_____ PY ({row['difficultyPY']}) _____

{wrap_text_with_max_width(row['reasonsPY'])}

_____ What are the differences between Jayvee and Python that influence how easy / hard it is to understand data pipelines? _____
_____ (JV {row['difficultyJV']}, PY {row['difficultyPY']}) _____

{wrap_text_with_max_width(row['differences'])}
'''
)
# Out:
# No content in response 2, skipping.
# No content in response 6, skipping.
# No content in response 47, skipping.
